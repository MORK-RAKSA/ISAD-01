-- %% [markdown]
-- # [ISAD Assignment]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ISAD Assignment]    Script Date: 6/1/2024 3:08:04 PM ******/
CREATE DATABASE [ISAD Assignment]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ISAD Assignment', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\ISAD Assignment.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ISAD Assignment_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\ISAD Assignment_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [ISAD Assignment] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ISAD Assignment].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ISAD Assignment] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ISAD Assignment] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ISAD Assignment] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ISAD Assignment] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ISAD Assignment] SET ARITHABORT OFF 
GO
ALTER DATABASE [ISAD Assignment] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [ISAD Assignment] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ISAD Assignment] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ISAD Assignment] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ISAD Assignment] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ISAD Assignment] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ISAD Assignment] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ISAD Assignment] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ISAD Assignment] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ISAD Assignment] SET  DISABLE_BROKER 
GO
ALTER DATABASE [ISAD Assignment] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ISAD Assignment] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ISAD Assignment] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ISAD Assignment] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ISAD Assignment] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ISAD Assignment] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [ISAD Assignment] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ISAD Assignment] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [ISAD Assignment] SET  MULTI_USER 
GO
ALTER DATABASE [ISAD Assignment] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ISAD Assignment] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ISAD Assignment] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ISAD Assignment] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ISAD Assignment] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [ISAD Assignment] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [ISAD Assignment] SET QUERY_STORE = ON
GO
ALTER DATABASE [ISAD Assignment] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [raksamork]

-- %%
USE [ISAD Assignment]
GO

-- %%
/****** Object:  User [raksamork]    Script Date: 6/1/2024 3:08:04 PM ******/
CREATE USER [raksamork] WITHOUT LOGIN WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [dbo].[tbLogin]

-- %%
/****** Object:  Table [dbo].[tbLogin]    Script Date: 6/1/2024 3:08:04 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbLogin](
	[username] [nchar](50) NULL,
	[password] [nchar](16) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [ISAD Assignment]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ISAD Assignment] SET  READ_WRITE 
GO
